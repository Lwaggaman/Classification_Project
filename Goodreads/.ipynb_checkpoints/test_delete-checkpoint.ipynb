# %%
import pandas as pd
from collections import OrderedDict
import seaborn as sns
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import f1_score

# %%
data = pd.read_csv('users_history.csv')

# %%
data.user_id.nunique()
# Out:
# 1602

# %%
data.shape
# Out:
# (233178, 13)

# %%
hist = data.iloc[:100000]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 219166 entries, 0 to 219165
# Data columns (total 13 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   id                             219166 non-null  int64
#  1   rating                         219166 non-null  int64
#  2   started_at                     96583 non-null   object
#  3   read_at                        125865 non-null  object
#  4   book.id.#text                  219166 non-null  int64
#  5   book.isbn13.@nil               21232 non-null   object
#  6   book.text_reviews_count.#text  219166 non-null  int64
#  7   book.num_pages                 199737 non-null  float64
#  8   book.publication_year          193364 non-null  float64
#  9   book.average_rating            219166 non-null  float64
#  10  book.ratings_count             219166 non-null  int64
#  11  user_id                        219166 non-null  int64
#  12  book.isbn13                    125582 non-null  object
# dtypes: float64(3), int64(6), object(4)
# memory usage: 21.7+ MB

# %%
# Import Reviewers
users = pd.read_csv('users_jellicoe.csv')
user_ids = []
for user in users.user_url:
    user_ids.append(''.join(filter(lambda i: i.isdigit(), user)))
users['user_id'] = user_ids
users = users.iloc[:,[-1,6]]

# %%
hist['read_at'], hist['started_at'] = pd.to_datetime(hist['read_at']), pd.to_datetime(hist['started_at'])
hist['rating_bias'] = hist['rating'] - hist['book.average_rating']
hist['reading_time'] = hist['read_at'] - hist['started_at']
# Out:
# /var/folders/tv/8qzgqvq554vgrs4zb6bwbwlm0000gn/T/ipykernel_4080/404577756.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hist['read_at'], hist['started_at'] = pd.to_datetime(hist['read_at']), pd.to_datetime(hist['started_at'])
# /var/folders/tv/8qzgqvq554vgrs4zb6bwbwlm0000gn/T/ipykernel_4080/404577756.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hist['rating_bias'] = hist['rating'] - hist['book.average_rating']
# /var/folders/tv/8qzgqvq554vgrs4zb6bwbwlm0000gn/T/ipykernel_4080/404577756.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hist['reading_time'] = hist['read_at'] - hist['started_at']

# %%
hist.reading_time.mean()
# Out:
# Timedelta('11 days 06:40:05.076923076')

# %% [markdown]
# #### Reader Level Features

# %%
reader_features = (['reader_avg_publ_year', 'reader_med_reading_time', 'reader_avg_rating', 'reader_avg_book_length',
                    'reader_avg_book_rating','reader_avg_rating bias', 'reader_avg_book_popularity',])

df_reader_feats = (hist.groupby(['user_id'], as_index=False).agg(OrderedDict([('book.publication_year','mean'),
                                                                              ('reading_time', 'median'),
                                                                              ('rating', 'mean'),
                                                                              ('book.average_rating', 'mean'),
                                                                              ('book.num_pages', 'mean'),
                                                                              ('rating_bias', 'mean'),
                                                                              ('book.ratings_count', 'mean')])))
df_reader_feats.columns = ['user_id'] + reader_features

# %%
# IDK why the merge doesn't work with object type
df_reader_feats['user_id'] = df_reader_feats.user_id.astype('int')
users['user_id'] = users.user_id.astype('int')
df_X = df_reader_feats.merge(users, how='left', on='user_id')

# Convert rating to target
df_X['rating'] = df_X.rating.apply(lambda x: x>=4).astype(int)

# %%
sns.pairplot(df_X, hue='rating', plot_kws=dict(alpha=.3, edgecolor='none'))

# %%
X_tr, X_te, y_tr, y_te = get_reader_split_data(df_X)

lr = LogisticRegression(C=100)
lr.fit(X_tr, y_tr)
f1_score(lr.predict(X_te), y_te)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/tv/8qzgqvq554vgrs4zb6bwbwlm0000gn/T/ipykernel_4080/1214953642.py in <module>
#       2
#       3 lr = LogisticRegression(C=100)
# ----> 4 lr.fit(X_tr, y_tr)
#       5 f1_score(lr.predict(X_te), y_te)
#
# /opt/anaconda3/envs/metis/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1506             _dtype = [np.float64, np.float32]
#    1507
# -> 1508         X, y = self._validate_data(
#    1509             X,
#    1510             y,
#
# /opt/anaconda3/envs/metis/lib/python3.9/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     574                 y = check_array(y, **check_y_params)
#     575             else:
# --> 576                 X, y = check_X_y(X, y, **check_params)
#     577             out = X, y
#     578
#
# /opt/anaconda3/envs/metis/lib/python3.9/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     954         raise ValueError("y cannot be None")
#     955
# --> 956     X = check_array(
#     957         X,
#     958         accept_sparse=accept_sparse,
#
# /opt/anaconda3/envs/metis/lib/python3.9/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     655
#     656         if all(isinstance(dtype, np.dtype) for dtype in dtypes_orig):
# --> 657             dtype_orig = np.result_type(*dtypes_orig)
#     658
#     659     if dtype_numeric:
#
# <__array_function__ internals> in result_type(*args, **kwargs)
#
# TypeError: invalid type promotion

# %%
df_X.iloc[:,1:-1]
# Out:
#      reader_avg_publ_year reader_med_reading_time  reader_avg_rating  \
# 0             2009.520202         3 days 00:00:00           3.420000
# 1             2018.000000         4 days 00:00:00           2.840000
# 2             2015.042781                     NaT           3.465000
# 3             2019.028571  2 days 13:38:51.500000           3.705000
# 4             2016.584211                     NaT           3.820000
# ..                    ...                     ...                ...
# 561           2016.182353                     NaT           0.000000
# 562           2003.859375                     NaT           3.190000
# 563           2012.846154  1 days 02:45:18.500000           4.000000
# 564           2007.604167                     NaT           3.555556
# 565           2010.000000                     NaT           2.827586
#
#      reader_avg_book_length  reader_avg_book_rating  reader_avg_rating bias  \
# 0                  3.873150              328.835979               -0.453150
# 1                  3.977300              304.274725               -1.137300
# 2                  4.049500              321.682292               -0.584500
# 3                  4.001700              343.277778               -0.296700
# 4                  3.980650              277.416667               -0.160650
# ..                      ...                     ...                     ...
# 561                4.058050              413.756757               -4.058050
# 562                3.948300              352.257732               -0.758300
# 563                4.100000              364.461538               -0.100000
# 564                3.983704              354.460000               -0.428148
# 565                4.010690              348.034483               -1.183103
#
#      reader_avg_book_popularity
# 0                  1.122836e+05
# 1                  5.879717e+04
# 2                  2.007522e+05
# 3                  4.948555e+04
# 4                  5.286859e+04
# ..                          ...
# 561                3.663628e+05
# 562                1.349977e+05
# 563                2.823586e+05
# 564                6.316307e+05
# 565                1.867749e+06
#
# [566 rows x 7 columns]

# %%
def get_reader_split_data(df, test_size=.2, seed=42):

    rs = np.random.RandomState(seed)
    
    total_readers = users['user_id'].unique() 
    test_readers = rs.choice(total_readers,
                             size=int(total_readers.shape[0] * test_size),
                             replace=False)

    df_tr = df[~df['user_id'].isin(test_readers)]
    df_te = df[df['user_id'].isin(test_readers)] 

    y_tr, y_te = df_tr['rating'], df_te['rating']
    X_tr, X_te = df_tr.iloc[:,1:-1], df_te.iloc[:,1:-1]

    return X_tr, X_te, y_tr, y_te
