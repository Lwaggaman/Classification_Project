# %%
import pandas as pd
import json

# %%
df = pd.read_csv('tiktokdata.csv')

# %%
json_df = pd.read_json('tiktokdata.json')
json_df
# Out:
#                      id             secretID  \
# 0   7035755786949299200  7035755786949299200
# 1   7029850867612306432  7029850867612306432
# 2   7032708613193894912  7032708613193894912
# 3   7037883701769849856  7037883701769849856
# 4   7027972743002115072  7027972743002115072
# 5   7029492249532713984  7029492249532713984
# 6   7031560420783672320  7031560420783672320
# 7   7031298990234749952  7031298990234749952
# 8   7028716557119392768  7028716557119392768
# 9   7032364143357201408  7032364143357201408
# 10  7026389342956555264  7026389342956555264
# 11  7028311977646754816  7028311977646754816
# 12  7029003038669065216  7029003038669065216
# 13  7031552646020369408  7031552646020369408
# 14  7033501036618730496  7033501036618730496
# 15  7027179831989226496  7027179831989226496
# 16  7039852510273637376  7039852510273637376
# 17  7031661390121372672  7031661390121372672
# 18  7029690566367513600  7029690566367513600
# 19  7029075891707726848  7029075891707726848
# ...

# %%
type(json_df.iloc[2,4])
# Out:
# dict

# %%
json_df.iloc[0,4]
# Out:
# {'id': '7022611108545545222',
#  'secUid': 'MS4wLjABAAAAYd6gJ5TfG4GOXaYXjFY9f7-1wzuN1cA2aY9UJop8R3cLDPM6i6CwCat9nxEcUSbi',
#  'name': 'alistofreads',
#  'nickName': 'alistofreads',
#  'verified': False,
#  'signature': 'A gal who reads - mostly literary fiction\n2022 📚: 0/100\n📍DC\n📧 + wishlist ⬇️',
#  'avatar': 'https://p16-sign.tiktokcdn-us.com/tos-useast5-avt-0068-tx/a2d377816d22b133f28fad083cd209ef~c5_1080x1080.jpeg?x-expires=1641366000&x-signature=%2FSniybvv9je4DykUmL7UR%2BuOpO0%3D',
#  'following': 110,
#  'fans': 9431,
#  'heart': 672900,
#  'video': 57,
#  'digg': 379}

# %%
json_df.iloc[2,4]['id']
# Out:
# '6943284462445134854'

# %%
for bio in json_df.iloc[0,4]:
    print(bio)
    print('------')
# Out:
# id
# ------
# secUid
# ------
# name
# ------
# nickName
# ------
# verified
# ------
# signature
# ------
# avatar
# ------
# following
# ------
# fans
# ------
# heart
# ------
# video
# ------
# digg
# ------

# %%
with open("tiktokdata.json", "r") as read_file:
    data = json.load(read_file)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# C:\Users\LAURAW~1\AppData\Local\Temp/ipykernel_6644/1247794280.py in <module>
#       1 with open("tiktokdata.json", "r") as read_file:
# ----> 2     data = json.load(read_file)
#
# ~\anaconda3\lib\json\__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#
# ~\anaconda3\lib\encodings\cp1252.py in decode(self, input, final)
#      21 class IncrementalDecoder(codecs.IncrementalDecoder):
#      22     def decode(self, input, final=False):
# ---> 23         return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#      24
# ...

# %%
for bio in df.iloc[:,9]:
    print(bio)
    print('-----')
# Out:
# A gal who reads - mostly literary fiction
# 2022 📚: 0/100
# 📍DC
# 📧 + wishlist ⬇️
# -----
# God is good
# I like fashion kpop and books
# Elementary school librarian
# -----
# 🥀 maddie 🥀
#
# 24 | boston | booktok
#
# 🌿 queer writer & reader 🌿
# -----
# Hi👋🏾 I’m Keontae 🙋🏾‍♂️
# KING OF “THAT’S CRAZY” 👑
# ROAD TO 450k 🚀
# MERCH👇🏾🥳
# -----
# @journeybookclub on insta ❤️ #booktok
# -----
# Eliminating Baltimore’s book deserts!
# VENMO: @StorybookMaze
# Amazon 📚wishlist ⬇
# -----
# 24 🦋 CA
# -----
# He/Him
# Latinx 🌈
# 📧KevinTylerNorman@gmail.com
# •📚
# -----
# IG  literarylola
# 💌 literarylolaslibrary@gmail.com
# YouTube & Goodreads⬇️🤍
# -----
# reading is romantic
# 💌staceyyu@gmail.com
# my fav books👇
# -----
# I have a cool shelf
# 📚
# Cr: Covet (Reread) 🩸🐉
# -----
# 15yr Trauma Counselor
# PODCAST LIVE in LINK!!
# LIVE sun 12pm EST
# 18+ MH field
# -----
# Same kid from West Philly.
# -----
# Seattle
# Red Wine and Books
# 📧: readingwithashleymay@gmail.com
# -----
# They/them
# 19
# ...

# %%
df['authorMeta.signature']
# Out:
# 0     A gal who reads - mostly literary fiction\n202...
# 1     God is good\nI like fashion kpop and books \nE...
# 2     🥀 maddie 🥀  \n\n24 | boston | booktok\n\n🌿 que...
# 3     Hi👋🏾 I’m Keontae 🙋🏾‍♂️\nKING OF “THAT’S CRAZY”...
# 4                 @journeybookclub on insta ❤️ #booktok
# 5     Eliminating Baltimore’s book deserts! \nVENMO:...
# 6                                               24 🦋 CA
# 7     He/Him\nLatinx 🌈\n📧KevinTylerNorman@gmail.com\n•📚
# 8     IG  literarylola \n💌 literarylolaslibrary@gmai...
# 9     reading is romantic\n💌staceyyu@gmail.com\nmy f...
# 10        I have a cool shelf\n📚\nCr: Covet (Reread) 🩸🐉
# 11    15yr Trauma Counselor\nPODCAST LIVE in LINK!!\...
# 12                           Same kid from West Philly.
# 13    Seattle\nRed Wine and Books \n📧: readingwithas...
# 14                                   They/them\n19\nnyc
# 15    ToG obsession⚔️\nBooks are the reason I need t...
# 16    CR: all of us villains\nGoal: 120/52\nshanbook...
# ...
